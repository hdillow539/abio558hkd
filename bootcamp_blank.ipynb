# %% [markdown]
# # bootcamp
#
#
# ## bootcamp learning goals
# 0. Create your GitHub repository and open a jupyter notebook (15 minutes)
# 1. Create, edit, and run Jupyter notebooks (15 minutes)
# 2. Assign and inspect variables (20 minutes)
# 3. Understand Python data types (10 minutes)
# 4. Create, index and manipulate containers (15 minutes)
# 5. Use functions and libraries (15 minutes)
# 6. Use numpy to compute with arrays and matrices (20 minutes)
# 7. Use Matplotlib to visualize data (20 minutes)
#
# ---
# ## How to use this notebook during class
# - Follow along as we go
# - Use your **Cards** to indicate where you're at:
#     - A **🟩Green card** means you are caught up with Max and **ready to help your classmates**
#     - A **🟥Red card** means you are stuck and need help
# - <span style='color:red;'>EXERCISE</span> — work on this problem by yourself, or try with a partner if you get stuck
# ---
# ## Resources and more practice:
# For this and many future exercises, you can find more guidance at the excellent **software carpentry** website
# - https://swcarpentry.github.io/python-novice-gapminder/

# %% [markdown]
# # 1) Create, edit, and run Jupyter notebooks
# - A notebook is a mix of **Markdown** (text) and **code** cells.
# - Click a cell to select it. Press **Shift+Enter** (or the ▶️ button) to **run** it.
# - To add a new cell: use the **+** button or press **B** (below) or **A** (above).
# - To delete a cell: use the **🗑️** button on the right, or double-tap **D**
# - To switch a cell to Markdown: press **M**. To code: press **Y**.
# - Save your work frequently (**Ctrl/Cmd+S**).

# %% [markdown]
# ### Edit vs. Command mode
# When a cell is **selected**, it has a blue bar to the left.
#
# A **selected** cell can be in one of two modes:
# 1. **Edit** mode: the cell is bounded by a blue box, and has a cursor in it. You can edit text in the cell like in any text editor
# 2. **Command** mode: you can run, move, and delete cells, but you can't type directly into the cell.
#
# #### To switch from **Edit** to **Command**:
# - press **Esc** to switch to **Command** without running the cell
# - or press **Shift+Enter** to run the cell and select the next cell in **Command** mode
#
# #### To switch from **Command** to **Edit**:
# - Press **Enter** or **double click the cell**

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 1</span>: Add a Markdown note (2 minutes)
# 1. Insert a new cell *below* this one (press **B**).
# 2. Switch it to **Markdown** (press **M**).
# 3. Type a short note with a header, e.g. `# My first note`.
# 4. Run it (Shift+Enter).

# %% [markdown]
# # this is a note and it should not run anything, pound sign in box leads to header
#
# empty space between the two line should allow it to be a subscript
# small note. When text is blue in box it is a header

# %% [markdown]
# # This is a header

# %% [markdown]
# Now let's run some code

# %%
print('Hello')
# Out:
# Hello

# %% [markdown]
# The above is **Python code**. You can also run some **bash** commands from within Jupyter. Sometimes this just works, as in:
#
# `pwd` (print working directory)
#
# but you may have to have a `!` prefix to tell Jupyter that what comes next is a bash command, as in:
#
# `!pwd`

# %%
pwd
# Out:
# 'C:\\Users\\hdill\\OneDrive\\Documents\\GitHub\\abio558hkd'

# %% [markdown]
#     - The workin dirctory is above, should keep this for all other files for class

# %%
ls
# Out:
#  Volume in drive C is OS
#  Volume Serial Number is 42A7-3119
#
#  Directory of C:\Users\hdill\OneDrive\Documents\GitHub\abio558hkd
#
# 09/21/2026  11:18 AM    <DIR>          .
# 09/21/2026  10:54 AM    <DIR>          ..
# 09/21/2026  10:54 AM                66 .gitattributes
# 09/21/2026  10:54 AM             3,910 .gitignore
# 09/21/2026  11:05 AM    <DIR>          .ipynb_checkpoints
# 09/21/2026  11:18 AM            32,669 bootcamp_blank.ipynb
# 09/21/2026  10:54 AM             1,087 LICENSE
# 09/21/2026  10:54 AM                61 README.md
#                5 File(s)         37,793 bytes
#                3 Dir(s)  75,081,113,600 bytes free

# %% [markdown]
# ### Comments
# Comments are bits of code that do not run, and are just for human eyes. Use comments to:
# - Describe what your code is doing, or why
#     - **Your most important code reader is your future self. Be kind to yourself and comment your code!**
# - Add instructions to users for how to use the code
# - (When developing code) temporarily hide/show bits of code that you are playing with and don't want to delete, or give yourself reminders or ToDo tasks
#
# #### In python a comment is indicated by the # symbol
# #### You can toggle between commented/uncommented for a whole line by pressing **Cmd+/** (Mac) or **Ctrl+/** (Windows)
#
#
# Let's try writing some comments, and toggling between commented / uncommented...

# %%
# make sure to have no short names or abbrevations because it will be terrible for later use
print('working')
# Out:
# working

# %% [markdown]
# ## Running, restarting, and saving
# - If things get messy, you can **Restart Kernel** (clears variables) and then **Run All**.
# - You can also **Restart Kernel and Clear Outputs of All Cells** (under the **Kernel** file menu) to reset the notebook entirely.
# - Save this notebook and consider exporting as HTML or PDF for your records (File → Export).

# %% [markdown]
# ### Summary: Interacting with notebooks
# - Use **markdown** to show nicely formatted text
# - Use **code** to ... code
# - Use **comments** to make your code more readable

# %% [markdown]
# # 2) Assign and inspect variables
# ℹ️ A **variable** stores a value. In Python, you create a variable the first time you assign to it.
#
# **Rules of thumb**
# - Use meaningful names: `temperature_c`, `subject_count`.
#     - NOT: `x`, `variable`, `number`
#     - **Be kind to your future self!**
# - Names use letters, numbers, and underscores (and **cannot** start with a number).
# - Python is case-sensitive: `Mass` ≠ `mass`.
#
# Let's define some variables, and then display them with print()

# %%
temperature_c = 22.5
n_samples = 100
genotype = 'w[118]'
is_control = True
print(temperature_c, n_samples, genotype, is_control)
# Out:
# 22.5 100 w[118] True

# %% [markdown]
# #### Sounds obvious but: You must **assign** a variable before you **call** it
#
# Let's see what happens when you do it in the wrong order...

# %%
# program reads from top down, so don't need to necessarily have all variabiles at the start
# but it needs to immideaitly precede the function that is calling it
strain = 'C57BL/6'
print(strain)
# Out:
# C57BL/6

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 2</span>: Fix this bug! (2 min)
# Change the code in the cell above 👆 to fix the bug and print the strain

# %%
pip install jupyterlab-spellchecker
# Out:
# ...
#    ---------------------------------------- 0.0/5.3 MB ? eta -:--:--
#    --------- ------------------------------ 1.3/5.3 MB 8.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 8.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 8.6 MB/s eta 0:00:01
#    ----------------------- ---------------- 3.1/5.3 MB 8.6 MB/s eta 0:00:01
#    ------------------------------------- -- 5.0/5.3 MB 4.9 MB/s eta 0:00:01
#    ---------------------------------------- 5.3/5.3 MB 4.8 MB/s  0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ### Useful aside: String formatting
# There are several methods to insert variables into a string. Let's practice one method called an **f-string**

# %%
name = 'Hayden'
age = '26'
message = f'My name is {name}, I am {age} years old'
# the f string function uses ' to start and end, needs to be printed 
print(message)
# Out:
# My name is Hayden, I am 26 years old

# %% [markdown]
# *Important note*: Re-assigning a variable updates its value

# %%
n_samples = 10

# %%
n_samples = n_samples + 5 
print(n_samples)
# Out:
# 15

# %% [markdown]
# ### Simple math
# Python has basic math operations built in.
# `+` `-` `*` `/`
#
# `**` - exponential

# %%
weeks = 5 
days = weeks*7
print(days)
# Out:
# 35

# %%
width = 15 
area = width ** 3
print(area)
# Out:
# 3375

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 3</span>: What does // mean? (4 min)
# There is an `//` operator - figure out what it does by inserting different numbers before and after it

# %%
operator_fucntion = 15//14
# division round down to keep the floor interger is function of // 
print (operator_fucntion)
# Out:
# 1

# %% [markdown]
# ### Inspecting what is in memory
# You can ask Python/IPython what's currently defined using the magic word %whos

# %%
# %whos
# Out:
# Variable            Type     Data/Info
# --------------------------------------
# age                 str      26
# area                int      3375
# days                int      35
# genotype            str      w[118]
# is_control          bool     True
# message             str      My name is Hayden, I am 26 years old
# n_samples           int      15
# name                str      Hayden
# operator_fucntion   int      1
# strain              str      C57BL/6
# temperature_c       float    22.5
# weeks               int      5
# width               int      15

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 4</span>: Variables practice (6 min)
# 1. Create variables for a sample: `mass_g`, `volume_L`. Assign them numbers.
# 2. Compute density in g/L and store it in `density_g_per_L`.
# 3. Print a sentence summarizing the result with the units.

# %%
mass_g = 161.7
volume_L = 45 
density_g_per_L = mass_g / volume_L 
message_density = f'The density of this object is {density_g_per_L:.2f}, and it is a number.'
# the :.number f tells the preceding variabile that is being called to float two decimals after the interger
print(message_density)
# Out:
# The density of this object is 3.59, and it is a number.

# %% [markdown]
# # 3) Inspect, understand, and convert Python data types
# Common built-in scalar types we'll use today:
# - `int` (integers), `float` (decimal numbers), `bool` (True/False), and `str` (text).
#
# Python variables are *dynamically* typed. This means that when you define a variable Python is smart and figures out what the data type should be. This is convenient but can be dangerous.
#
# Use `type(obj)` to check the type.

# %% [markdown]
# ### Converting between types
# You can convert between some data types using constructor functions: `int()`, `float()`, `str()`, `bool()`.
# - Not every conversion is possible (e.g., `int('3.14')` raises an error).
# - `bool(x)` is `False` for 0, 0.0, empty strings `''`, and empty containers; otherwise `True`.

# %%
int('3.14')
# Out:
# ----------------------------------------------------------------
# ValueError                     Traceback (most recent call last)
# Cell In[37], line 1
# ----> 1 int('3.14')
#
# ValueError: invalid literal for int() with base 10: '3.14'

# %%
float('42')
# Out:
# 42.0

# %%
str(3.14)
# Out:
# '3.14'

# %% [markdown]
# ### Booleans and comparisons
# Comparison operators: `==`, `!=`, `<`, `<=`, `>`, `>=`.
# Logical operators: `and`, `or`, `not`.

# %%
#comparision operators always return a boolean response ie true or false 
# not is the equivalent of oppisitie day for the fucntion within it 
(3 == 5), (3!=5)
# Out:
# (False, True)

# %% [markdown]
# ### Strings: indexing, slicing, and methods
# Strings are sequences of characters.
# - Indexing: `s[0]` (first char); Slicing: `s[0:4]` (chars 0–3).
# - Length: `len(s)`.
#
# Let's practice indexing into a string. You will be using indexing A LOT for other data types (like lists or arrays of numbers) later in the class. and the syntax is similar

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 5</span>: Types & conversions (5 min)
# Given the strings below, compute the force `F = m * a` and print a friendly summary.
#
# ```python
# mass_str = '12.5'      # grams
# accel_str = '9.81'     # m/s^2
# ```
#
# Steps:
# 1. Convert both to floating-point numbers.
# 2. Convert mass to **kilograms** first (1 g = 0.001 kg).
# 3. Compute force in Newtons using F = m * a. A newton is 1 kg * m/s^2
# 4. Print a sentence displaying the computed force in N

# %% [markdown]
# # 4. Create, index and manipulate containers
#
# A **container** is a data structure that stores a collection of objects
#
# There are a few examples of containers, including:
# - **string**: A container full of characters like "hello"
# - **list**: A container full of whatever, separated by commas, like: [1, 2, 3.5, 50]
# - **tuple**: a lot like a list but it is _immutable_
# - immutable cannot not be changed so assuming unable to update it via math?

# %% [markdown]
# What can you do with a container? Here are two things:
# 1. Index to retrieve or change values
# 2. Math!
#
# Let's make a list and see what both of these look like:

# %%
my_list = [0,8,2,4]
print(my_list)
type (my_list)
# Out:
# [0, 8, 2, 4]
# list

# %%
my_list[3]
# Out:
# 4

# %%
my_list[1:]
# Out:
# [8, 2, 4]

# %%
my_list[1:3]
# number : open collects everything from stated position to end of list
# x:y returns list numbers that are the difference in value of x and y
# Out:
# [8, 2]

# %% [markdown]
# Python has some built in math functions, too...

# %%
print(sum(my_list))
print(min(my_list))
print(my_list)
# Out:
# 14
# 0
# [0, 8, 2, 4]

# %% [markdown]
# ### <span style='color:red;'>EXERCISE 6</span>: LIST MATH (5 min)
# Make a list of numbers and then write some code to compute the average of the values

# %%
average_my_list = sum(my_list)/len(my_list)
print(average_my_list)
# Out:
# 3.5

# %% [markdown]
# # 5) Use functions and libraries
# When you install Python, it includes a **built-in** set of **functions** and **libraries**
# - A **function** is a bit of code that takes an input, does something with it, and returns an output
# - A **library** is a collection of code that can dramatically extend the functionality Python
#
# A function uses parentheses () to input the **argument(s)**
#
# You already know (at least) one Python function from last time: print()

# %% [markdown]
# ### Finding help for a function
# 1. use the help() function
# 2. Google it!

# %%
help()
# Out:
# Welcome to Python 3.14's help utility! If this is your first time using
# Python, you should definitely check out the tutorial at
# https://docs.python.org/3.14/tutorial/.
#
# Enter the name of any module, keyword, or topic to get help on writing
# Python programs and using Python modules.  To get a list of available
# modules, keywords, symbols, or topics, enter "modules", "keywords",
# "symbols", or "topics".
#
# You can use the following keyboard shortcuts at the main interpreter prompt.
# F1: enter interactive help, F2: enter history browsing mode, F3: enter paste
# mode (press again to exit).
#
# Each module also comes with a one-line summary of what it does; to list
# the modules whose name or summary contain a given string such as "spam",
# enter "modules spam".
#
# To quit this help utility and return to the interpreter,
# enter "q", "quit" or "exit".
# help>  average
# No Python documentation found for 'average'.
# Use help() to get the interactive help utility.
# ...

# %% [markdown]
# ### Making your own function
#
# You can define your own functions! Let's see how that works...

# %%
def compute_average(list_values): 
    avg_value = sum(list_values) / len(list_values)
    return avg_value
    # need to make sure that the function is defined and the cell that calls the function is run so it is in
    # the intterparoator

# %% [markdown]
# OK now let's use our new function

# %%
compute_average([20,30,100,9])
# Out:
# 39.75

# %% [markdown]
# OK cool our function works, but let's imagine someone else using it, or you using it weeks from now...

# %%
def compute_average(list_values): 
    """
    calculates the average of the numbers in list_numbers 

    inputs: list_numbers, should be a list of numbers 
    outputs: avg_value, scalar

    """
    avg_value = sum(list_values) / len(list_values)
    return avg_value

# %%
help(compute_average)
# Out:
# Help on function compute_average in module __main__:
#
# compute_average(list_values)
#     calculates the average of the numbers in list_numbers
#
#     inputs: list_numbers, should be a list of numbers
#     outputs: avg_value, scalar

# %% [markdown]
# ** Good functions help the user understand how to use them, and prevent users from mis-using them. Let's improve our function with some **documentation** and some **input validation**

# %% [markdown]
# ## Libraries
# Python doesn't have that many **built-in** **functions** - they are listed here:
# https://docs.python.org/3/library/functions.html
#
# If this were all we were limited to, Python would not be very useful for the sciences
#
# Python is expandable because of **libraries**
# To use a **library** you need to first **import** it

# %% [markdown]
# ### Importing NumPy and Matplotlib
# Let's import two community libraries:
# - **numpy** is for numerical computing
# - **Matplotlib** is for plotting
#
# These libraries must be installed before you can use them. If you are using the full Anaconda distribution, you should already have **numpy** and **matplotlib**, if not, you may need to install it
#
# We'll import numpy and the plotting module of matplotlib, called pyplot, with a shortcut variable to refer to them...

# %%
# %pip install numpy
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
# %pip install matplotlib
# Out:
# ...
#   Using cached cycler-0.12.1-py3-none-any.whl.metadata (3.8 kB)
# ...
#    ---------------------------------------- 0.0/9.5 MB ? eta -:--:--
#    -- ------------------------------------- 0.5/9.5 MB 3.6 MB/s eta 0:00:03
#    ------ --------------------------------- 1.6/9.5 MB 4.4 MB/s eta 0:00:02
#    ------------ --------------------------- 2.9/9.5 MB 5.0 MB/s eta 0:00:02
#    ---------------- ----------------------- 3.9/9.5 MB 5.1 MB/s eta 0:00:02
#    -------------------- ------------------- 5.0/9.5 MB 5.3 MB/s eta 0:00:01
#    ------------------------- -------------- 6.0/9.5 MB 5.0 MB/s eta 0:00:01
#    ---------------------------- ----------- 6.8/9.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------------- -------- 7.6/9.5 MB 4.9 MB/s eta 0:00:01
#    ------------------------------------ --- 8.7/9.5 MB 4.8 MB/s eta 0:00:01
#    ---------------------------------------  9.4/9.5 MB 4.7 MB/s eta 0:00:01
#    ---------------------------------------- 9.5/9.5 MB 4.6 MB/s  0:00:02
# ...

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %% [markdown]
# # 6) Use numpy to create and compute with arrays and matrices

# %% [markdown]
# ### Using arrays in Numpy
# One of the big advantages of Numpy is that it has built in data types called arrays, which can be 1D (like a vector) or n-dimensional (like a matrix)
#
# Let's start by making a 1D array...

# %%
counts = np.array([5,6,3,5,6,8])
print(counts)
type(counts)
np.sum(counts)
np.mean(counts)
# Out:
# [5 6 3 5 6 8]
# np.float64(5.5)

# %% [markdown]
# Indexing into numpy arrays works much like with other containers like lists

# %% [markdown]
# numpy gives us access to tools for computations on our arrays

# %% [markdown]
# ## <span style='color:red;'>EXERCISE 2</span>: LEARN NUMPY FUNCTIONS ON YOUR OWN (5 min)
# Use the wonders of the internet, or your intuition, to figure out how to compute the **median** and **variance** of _counts_ using numpy functions

# %% [markdown]
# # A note about searching for help online...
#
# Just Google it. Or ask a chatbot.
#
# Don't google or ask Chat "how do I do [complicated analysis pipeline] from start to finish" but Google "how do I compute this thing using Numpy" or "how do I use [this scipy function]" and then TEST the answer that you get.
#
# In this class, a lot of the exercises and even miniprojects we do can be reasonably well done by a decent chatbot. But I want you to resist the urge to outsource the work to a LLM. By writing your own code, especially while you are learning, you will give yourself a chance to understand the data and the algorithms.

# %% [markdown]
# ## matrices (ndarrays)
# Numpy also allows you to create matrices / n-dimensional arrays.
# Let's create a matrix to see how they work...

# %% [markdown]
# ## <span style='color:red;'>EXERCISE 3</span>: LEARN NUMPY FUNCTIONS ON YOUR OWN PT 2 (5 min)
# Look up the numpy.mean() documentation to figure out how to compute the mean...
# - across all rows (should be an array of length 3)
# - across all columns (should be an array of length 4)
# - across the whole matrix (should be a single, scalar number)
#
# https://numpy.org/doc/stable/reference/generated/numpy.mean.html

# %% [markdown]
# # 7) Use Matplotlib to visualize data
# numpy has functions for generating pseudo-random numbers. Let's try one by plucking random numbers from a uniform distribution
#
# Then we'll use **pyplot** to plot a histogram. Note there are lots of ways to create figure and axis objects with pyplot but I will teach you what I think is the most explicit (and best) way...

# %% [markdown]
# ## <span style='color:red;'>EXERCISE 4</span>: LEARN NUMPY FUNCTIONS ON YOUR OWN PT 3 (5 min)
# Look up the documentation for numpy.random distributions to see what random distributions numpy can draw from. Pick a distribution and some parameters, and then plot a histogram of 1000 draws from that distribution
#
# https://numpy.org/doc/2.1/reference/random/generator.html#distributions

# %% [markdown]
# ## BONUS: Modeling bacterial growth
#
# You are growing E. coli in a flask, and you measure optical density of the bacterial suspension using a spectrophotometer every 30 minutes for 5 hours.
# The optical density is directly related to the number of bacteria in the suspension

# %%
time_points = np.array([0, 0.5, 1, 1.5, 2, 2.5, 3, 3.5, 4, 4.5, 5])
optical_density = [30, 45, 92, 198, 404, 838, 1705, 3120, 3780, 4100, 4400]

# %% [markdown]
# Let's plot the data using **pyplot**

# %% [markdown]
# Part of this growth curve is the **exponential phase**, where the number of bacteria double at regular intervals. This interval is called the doubling time
#
# **N(t) = N_0 * 2^(t/T_d)**
# - N(t) is the number of bacteria as a function of time, t
# - N_0 is the initial number of bacteria
# - T_d is the doubling time

# %% [markdown]
# Let's transform our optical density by log2...
# This makes our equation
#
# Log2(N(t)) = Log2(N_0) + t/T_D
#
# which is linear, of the form Y = mx + b, where the **slope m = 1/T_d**

# %% [markdown]
# Now we're going to fit a line to our log-transformed data to estimate the doubling time. First note that the exponential phase is between about 0.5 and 3 hours...
